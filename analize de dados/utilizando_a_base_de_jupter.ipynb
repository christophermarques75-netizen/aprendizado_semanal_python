# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.decomposition import PCA

# %%
np.random.seed(42)

# %%
dados = pd.DataFrame({
    "horas_estudo": np.random.randint(1, 6, 50),
    "exercicios": np.random.randint(10, 100, 50),
    "frequencia": np.random.randint(60, 100, 50),
    "participacao": np.random.randint(1, 10, 50),
})

# %%
dados["nota_anterior"] = (
    dados["horas_estudo"] * 1.5
    + np.random.normal(0, 1, 50)
)

# %%
print("\n--- Primeiras linhas da base ---")
print(dados.head())
# Out:
# --- Primeiras linhas da base ---
#    horas_estudo  exercicios  frequencia  participacao  nota_anterior
# 0             4          69          83             4       5.425291
# 1             5          80          70             7       7.078502
# 2             3          53          76             3       4.839821
# 3             5          17          67             6       7.492620
# 4             5          56          94             2       8.267297

# %%
correlacao = dados.corr()

# %%
print("\n--- Matriz de correlação ---")
print(correlacao.round(3))
# Out:
# --- Matriz de correlação ---
#                horas_estudo  exercicios  frequencia  participacao  \
# horas_estudo          1.000      -0.036      -0.204         0.158
# exercicios           -0.036       1.000       0.049        -0.037
# frequencia           -0.204       0.049       1.000         0.104
# participacao          0.158      -0.037       0.104         1.000
# nota_anterior         0.908       0.005      -0.216         0.128
#
#                nota_anterior
# horas_estudo           0.908
# exercicios             0.005
# frequencia            -0.216
# participacao           0.128
# nota_anterior          1.000

# %%
dados_selecionados = dados.drop(columns=["nota_anterior"])

# %%
print("\n--- Dados após retirar nota_anterior ---")
print(dados_selecionados.head())
# Out:
# --- Dados após retirar nota_anterior ---
#    horas_estudo  exercicios  frequencia  participacao
# 0             4          69          83             4
# 1             5          80          70             7
# 2             3          53          76             3
# 3             5          17          67             6
# 4             5          56          94             2

# %%
scaler_engajamento = StandardScaler()

# %%
engajamento_padronizado = scaler_engajamento.fit_transform(
    dados[["frequencia", "participacao"]]
)

# %%
dados["engajamento_total"] = (
    engajamento_padronizado[:, 0]
    + engajamento_padronizado[:, 1]
)

# %%
print("\n--- Nova feature: engajamento_total ---")
print(
    dados[
        ["frequencia", "participacao", "engajamento_total"]
    ].head()
)
# Out:
# --- Nova feature: engajamento_total ---
#    frequencia  participacao  engajamento_total
# 0          83             4          -0.169964
# 1          70             7          -0.180392
# 2          76             3          -1.092136
# 3          67             6          -0.775865
# 4          94             2           0.027562

# %%
features_pca = [
    "horas_estudo",
    "exercicios",
    "frequencia",
    "participacao"
]

# %%
X = dados[features_pca]

# %%
scaler = StandardScaler()

# %%
X_padronizado = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)

# %%
componentes = pca.fit_transform(X_padronizado)

# %%
dados_pca = pd.DataFrame(
    componentes,
    columns=["Componente_1", "Componente_2"]
)

# %%
print("\n--- Dados após PCA ---")
print(dados_pca.head())
# Out:
# --- Dados após PCA ---
#    Componente_1  Componente_2
# 0      0.197160     -0.113268
# 1      1.528096      0.184873
# 2      0.035394     -0.779274
# 3      2.184055     -0.110169
# 4      0.161979     -0.046900

# %%
print("\n--- Variância explicada ---")
# Out:
# --- Variância explicada ---

# %%
print(
    "Componente 1:",
    round(pca.explained_variance_ratio_[0] * 100, 2),
    "%"
)
# Out:
# Componente 1: 30.86 %

# %%
print(
    "Componente 2:",
    round(pca.explained_variance_ratio_[1] * 100, 2),
    "%"
)
# Out:
# Componente 2: 27.49 %

# %%
print(
    "Total explicado pelos dois componentes:",
    round(
        pca.explained_variance_ratio_.sum() * 100,
        2
    ),
    "%"
)
# Out:
# Total explicado pelos dois componentes: 58.35 %
